# %%
import requests
from bs4 import BeautifulSoup
import selenium
from selenium import webdriver
import os
import io
import hashlib
import time
from PIL import Image
DRIVER_PATH = r"C:\Users\adity\Desktop\chromeDriver\chromedriver"

# %%
def fetch_image_urls(query:str, max_links_to_fetch:int, wd:webdriver, sleep_between_interactions:int=1):
    def scroll_to_end(wd):
        wd.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(sleep_between_interactions)    
    
    # build the google query
    search_url = "https://www.google.com/search?safe=off&site=&tbm=isch&source=hp&q={q}&oq={q}&gs_l=img"

    # load the page
    wd.get(search_url.format(q=query))

    image_urls = set()
    image_count = 0
    results_start = 0
    while image_count < max_links_to_fetch:
        scroll_to_end(wd)

        # get all image thumbnail results
        thumbnail_results = wd.find_elements_by_css_selector("img.Q4LuWd")
        number_results = len(thumbnail_results)
        
        print(f"Found: {number_results} search results. Extracting links from {results_start}:{number_results}")
        
        for img in thumbnail_results[results_start:number_results]:
            # try to click every thumbnail such that we can get the real image behind it
            try:
                img.click()
                time.sleep(sleep_between_interactions)
            except Exception:
                continue

            # extract image urls    
            actual_images = wd.find_elements_by_css_selector('img.n3VNCb')
            for actual_image in actual_images:
                if actual_image.get_attribute('src') and 'http' in actual_image.get_attribute('src'):
                    image_urls.add(actual_image.get_attribute('src'))

            image_count = len(image_urls)

            if len(image_urls) >= max_links_to_fetch:
                print(f"Found: {len(image_urls)} image links, done!")
                break
        else:
            print("Found:", len(image_urls), "image links, looking for more ...")
            time.sleep(30)
            return
            load_more_button = wd.find_element_by_css_selector(".mye4qd")
            if load_more_button:
                wd.execute_script("document.querySelector('.mye4qd').click();")

        # move the result startpoint further down
        results_start = len(thumbnail_results)

    return image_urls

# %%
def persist_image(folder_path:str,url:str):
    try:
        image_content = requests.get(url).content

    except Exception as e:
        print(f"ERROR - Could not download {url} - {e}")

    try:
        image_file = io.BytesIO(image_content)
        image = Image.open(image_file).convert('RGB')
        file_path = os.path.join(folder_path,hashlib.sha1(image_content).hexdigest()[:10] + '.jpg')
        with open(file_path, 'wb') as f:
            image.save(f, "JPEG", quality=85)
        print(f"SUCCESS - saved {url} - as {file_path}")
    except Exception as e:
        print(f"ERROR - Could not save {url} - {e}")

# %%
def search_and_download(search_term:str,driver_path:str,target_path='./images',number_images=60):
    target_folder = os.path.join(target_path,'_'.join(search_term.lower().split(' ')))

    if not os.path.exists(target_folder):
        os.makedirs(target_folder)

    with webdriver.Chrome(executable_path=driver_path) as wd:
        res = fetch_image_urls(search_term, number_images, wd=wd, sleep_between_interactions=0.5)
        
    for elem in res:
        persist_image(target_folder,elem)

# %%
search_term = "Turmeric root"
search_and_download(search_term = search_term,driver_path = DRIVER_PATH, number_images = 60)
# Out:
# Found: 100 search results. Extracting links from 0:100
# Found: 60 image links, done!
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ_lW-M4FxFSMMWfxkteqVYucIEwAZPElrW-A&usqp=CAU - as ./images\turmeric_root\8698ef0059.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQsBLYsEjfv6Z7RB_uVog7WBhg6iM-zOqL6jg&usqp=CAU - as ./images\turmeric_root\d816c9cdfa.jpg
# SUCCESS - saved https://rukminim1.flixcart.com/image/416/416/jy4q3680/plant-seed/n/3/b/20-turmeric-root-dia-original-imafgftchsebsbfd.jpeg?q=70 - as ./images\turmeric_root\b99c5ab970.jpg
# SUCCESS - saved https://5.imimg.com/data5/PD/FQ/MY-38034055/fresh-turmeric-root-500x500.jpg - as ./images\turmeric_root\b8bee4e9c6.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSBsr3rs6VJ_5rzpkQYAKf_1FZqOmv3BcuVXA&usqp=CAU - as ./images\turmeric_root\c823e9e74a.jpg
# SUCCESS - saved https://5.imimg.com/data5/FA/ZI/CP/SELLER-79003589/turmeric-500x500.jpg - as ./images\turmeric_root\3f1f8e15e2.jpg
# SUCCESS - saved https://i.pinimg.com/originals/30/8f/a1/308fa1fa85149c7070244947281ff609.jpg - as ./images\turmeric_root\c8d623ab17.jpg
# SUCCESS - saved https://images.indianexpress.com/2021/01/turmeric-root_1200_getty.jpg - as ./images\turmeric_root\fbdc968c1b.jpg
# SUCCESS - saved https://www.foodchamps.org/wp-content/uploads/2020/10/Freshly-Grinded-Turmeric-Root.jpg - as ./images\turmeric_root\d6e9059431.jpg
# SUCCESS - saved https://journal.rishi-tea.com/wp-content/uploads/2020/09/turmeric-roots.jpg - as ./images\turmeric_root\e68cf92e54.jpg
# SUCCESS - saved https://media.istockphoto.com/photos/set-or-collection-turmeric-powder-and-turmeric-root-isolated-on-white-picture-id1188479221 - as ./images\turmeric_root\06014fb0a3.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTIW_WehSH8dh2E1CLu0W7zurAZiHGYP0zfyg&usqp=CAU - as ./images\turmeric_root\82fedc5405.jpg
# SUCCESS - saved https://i.ytimg.com/vi/LC8n6JYlcc4/maxresdefault.jpg - as ./images\turmeric_root\40fa911f9f.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ8SE2kSkr3dxCIukRLs0rsXUUjaLIMHLfs4Q&usqp=CAU - as ./images\turmeric_root\48cc785e27.jpg
# SUCCESS - saved https://comps.canstockphoto.com/turmeric-root-and-some-slices-picture_csp46019373.jpg - as ./images\turmeric_root\955bc3fc25.jpg
# SUCCESS - saved https://qph.fs.quoracdn.net/main-qimg-24b6962b02b3449b7b800bccbc866ceb - as ./images\turmeric_root\72ff9f5279.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQGGRC1S0veigzNX-VcpNdwJc_N12Eqlred3A&usqp=CAU - as ./images\turmeric_root\0d78c029c5.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQYJIf1RIn5J19vPdllQMMXY-JHjqgzVUl0HA&usqp=CAU - as ./images\turmeric_root\eeddea6d00.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSezu7xdKzj0XZ3Q6a1v5z1Fllmu7ohR1mQNA&usqp=CAU - as ./images\turmeric_root\f945c1c6c3.jpg
# SUCCESS - saved https://img.webmd.com/dtmcms/live/webmd/consumer_assets/site_images/articles/health_tools/turmeric_slideshow/1800ss_thinkstock_rf_fresh_and_dried_turmeric_roots.jpg?resize=650px:* - as ./images\turmeric_root\eace43778f.jpg
# SUCCESS - saved https://tiimg.tistatic.com/fp/2/006/452/nigeria-origin-dried-turmeric-root-339.jpg - as ./images\turmeric_root\648f100e13.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS3VMCTZxdQz4lRKeVRtr6KbB28n0Ly88rPuQ&usqp=CAU - as ./images\turmeric_root\452f029d0b.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQVapRY8szoZk5dNd_Cdkf5trJMwgxUrlpHfg&usqp=CAU - as ./images\turmeric_root\e7724569b0.jpg
# SUCCESS - saved https://deepgreenpermaculture.files.wordpress.com/2020/10/img_20200908_19194617.jpg - as ./images\turmeric_root\641ea7c0e1.jpg
# SUCCESS - saved https://media.istockphoto.com/photos/turmeric-roots-isolated-on-white-background-pile-and-cut-turmeric-picture-id1169333608 - as ./images\turmeric_root\3416b69cee.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQpQTbt8F8DQOklfSVaCDExcW4CXBlJIehCiQ&usqp=CAU - as ./images\turmeric_root\db3b4bb6e7.jpg
# SUCCESS - saved https://st4.depositphotos.com/2714851/21394/i/1600/depositphotos_213947068-stock-photo-preparing-fresh-turmeric-root.jpg - as ./images\turmeric_root\8cde96d6e4.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS4gQ0V92lhWkluarhwsetK9OOdAwbLy0qeww&usqp=CAU - as ./images\turmeric_root\701b1a9f92.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQYJPF1RYOIzX6LAdzRrNgJ7O9r_6IhLZ1_ZQ&usqp=CAU - as ./images\turmeric_root\ab3e25da75.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTiTOU4mIYZmxa6XKD3zrz3Pp59pkTDrQu62w&usqp=CAU - as ./images\turmeric_root\df7daccc5a.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRLMmfvCDO62BKtIANb3phexx_k19pA2-URZw&usqp=CAU - as ./images\turmeric_root\6a7dd69e17.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR11KegLeFG2wmxr6fBTTeBqdj_vUVwn_F_QA&usqp=CAU - as ./images\turmeric_root\7bd4331746.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTNAgR5Hz6fzizd2yRQ1rds7OS30WW2tzQgZw&usqp=CAU - as ./images\turmeric_root\e8bbf339ff.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQC3yXPxru04C9ACjccaAYnZXU9l6ZPUKR7Ng&usqp=CAU - as ./images\turmeric_root\d5487855dc.jpg
# SUCCESS - saved https://m.media-amazon.com/images/I/41YvAqe0oWS.jpg - as ./images\turmeric_root\af2401e757.jpg
# SUCCESS - saved https://m.media-amazon.com/images/I/7119OzEpfyL._SL1500_.jpg - as ./images\turmeric_root\a29926f4a3.jpg
# SUCCESS - saved https://www.foodchamps.org/wp-content/uploads/2020/10/Turmeric-Root.jpg - as ./images\turmeric_root\a4bc92dedf.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSAhvIu6ohZJVfexP6nWPiBWf-DnhL_zh-6AA&usqp=CAU - as ./images\turmeric_root\d0fb1ff0df.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQrc7j9Lr1SbdXME26D6qAMwYkG5TyKc5tqWw&usqp=CAU - as ./images\turmeric_root\2ab6ebc2c7.jpg
# SUCCESS - saved https://i.pinimg.com/736x/32/d2/cd/32d2cdd7ddcba5c5257c28a0b4cb62f9.jpg - as ./images\turmeric_root\51d874b951.jpg
# SUCCESS - saved https://gardenerspath.com/wp-content/uploads/2019/03/Harvesting-Turmeric.jpg - as ./images\turmeric_root\3fc0b8bc45.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRH7Zl8k96p_NzuR852Y1ZMOi_ETE5RGuW4ng&usqp=CAU - as ./images\turmeric_root\88375a7684.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTT0jgWSmK9-eJYa8WLvvmZzfX5PEjYBOJAKQ&usqp=CAU - as ./images\turmeric_root\8fd46858de.jpg
# SUCCESS - saved https://m.media-amazon.com/images/I/81xSlcA87VS._SY445_.jpg - as ./images\turmeric_root\e0a6cb86df.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR9981Wi6MhTjWQBFU_w_hWhJoe3bmiozh74w&usqp=CAU - as ./images\turmeric_root\00b9abc6cc.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSDcUTfwg-63_m8jJR8RrN0HvSPfkomvNTtuQ&usqp=CAU - as ./images\turmeric_root\7e0db4000e.jpg
# SUCCESS - saved https://5.imimg.com/data5/FB/CJ/MY-9800673/fresh-turmeric-root-500x500.jpg - as ./images\turmeric_root\d2ce9990b8.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRnAKei9zKqIEnFYd3-M8QBST462esVoo-SwA&usqp=CAU - as ./images\turmeric_root\7a11e40c27.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTPRsou80VTO08PMEbKwTSqdfjzQusbaHbVww&usqp=CAU - as ./images\turmeric_root\6f72ac4fbe.jpg
# SUCCESS - saved https://cdn-prod.medicalnewstoday.com/content/images/articles/327/327455/turmeric-root-and-powder.jpg - as ./images\turmeric_root\5863449708.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTO8cOCTzaQn0vBiBc9RhcLoTB7kMZuk6rw6Q&usqp=CAU - as ./images\turmeric_root\02f4bfcaaf.jpg
# SUCCESS - saved https://5.imimg.com/data5/CG/UT/HF/SELLER-69048949/fresh-turmeric-root-500x500.jpg - as ./images\turmeric_root\2ad1063cc2.jpg
# SUCCESS - saved https://img3.exportersindia.com/product_images/bc-full/2020/12/5814569/turmeric-root-oil-1607247465-5649565.jpeg - as ./images\turmeric_root\b203bc1990.jpg
# SUCCESS - saved https://bagdarafarms.com/wp-content/uploads/2017/01/Fresh-Turmeric-min.jpg - as ./images\turmeric_root\4faea47b4a.jpg
# SUCCESS - saved https://www.nutrition-and-you.com/image-files/turmeric-01.jpg - as ./images\turmeric_root\ad18d18001.jpg
# SUCCESS - saved https://images.fineartamerica.com/images-medium-large-5/3-turmeric-root-science-photo-library.jpg - as ./images\turmeric_root\ae926fc778.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTDXUQzIe35rwVjdpXO-ryyjTQzCcgrNRY08w&usqp=CAU - as ./images\turmeric_root\d0c77fd468.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSEMElvtlBMLTUJnPnv7_A2tW1zNnBdUCYsmw&usqp=CAU - as ./images\turmeric_root\fbd2b41b7a.jpg
# SUCCESS - saved https://image.shutterstock.com/image-photo/cutting-turmeric-roots-isolated-on-260nw-552550477.jpg - as ./images\turmeric_root\1f7972e0cb.jpg
# SUCCESS - saved https://media.istockphoto.com/photos/turmeric-powder-with-fresh-turmeric-root-in-white-picture-id843526966 - as ./images\turmeric_root\724327da76.jpg
